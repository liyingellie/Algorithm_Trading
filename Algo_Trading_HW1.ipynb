# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Exerices 0：Load data from data.xlsx
# ## Preprocessing data in a correct and readable manner

# %%
# Read mutli-sheets in excel

xls = pd.ExcelFile('data.xlsx')
df1 = pd.read_excel(xls, 'Daily')
df2 = pd.read_excel(xls, '1hr')
df3 = pd.read_excel(xls, '5 min')
df4 = pd.read_excel(xls, '1min')
df5 = pd.read_excel(xls, 'Tick')

# %%
#data.head()
df1.head()
# Out:
#         AAPL US Equity Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                 Date    PX_OPEN    PX_HIGH     PX_LOW    PX_LAST  PX_VOLUME
# 1  2015-01-02 00:00:00     111.39     111.44     107.35     109.33   53204626
# 2  2015-01-05 00:00:00     108.29     108.65     105.41     106.25   64285491
# 3  2015-01-06 00:00:00     106.54     107.43     104.63     106.26   65797116
# 4  2015-01-07 00:00:00      107.2      108.2    106.695     107.75   40105934
#
#    Unnamed: 6              Unnamed: 7
# 0  NUM_TRADES  VOLUME_WEIGHTED_AVG_PX
# 1      287276                 109.133
# 2      317900                 106.784
# 3      364285                 106.114
# 4      222430                 107.646

# %%
df1['PX_OPEN'].describe()
# Out:
# count     252.00
# unique    236.00
# top       116.04
# freq        3.00
# Name: PX_OPEN, dtype: float64

# %%
df2.head()
# Out:
#         AAPL US Equity Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0              BarTp=T        NaN        NaN        NaN         NaN
# 1                 Date       OPEN       HIGH        LOW  LAST_PRICE
# 2  2016-01-04 09:30:00     102.61     103.69        102      102.67
# 3  2016-01-04 10:00:00     102.68     103.59     102.38      103.28
# 4  2016-01-04 10:30:00     103.28    103.935     103.01     103.338
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8     AAPL US Equity.1  \
# 0           NaN        NaN        NaN         NaN              BarTp=B
# 1  NUMBER_TICKS     VOLUME      VALUE         NaN                 Date
# 2         44010    9306102  956512128         NaN  2016-01-04 09:30:00
# 3         27462    4819634  496242144         NaN  2016-01-04 10:00:00
# 4         22162    3886368  401830496         NaN  2016-01-04 10:30:00
#
#       ...     Unnamed: 16 Unnamed: 17     AAPL US Equity.2 Unnamed: 19  \
# 0     ...             NaN         NaN              BarTp=A         NaN
# 1     ...           VALUE         NaN                 Date        OPEN
# 2     ...        31671954         NaN  2016-01-04 09:30:00      102.41
# 3     ...        47126300         NaN  2016-01-04 10:00:00      102.69
# 4     ...        40699960         NaN  2016-01-04 10:30:00      103.28
#
#   Unnamed: 20 Unnamed: 21 Unnamed: 22   Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0         NaN         NaN         NaN           NaN         NaN         NaN
# 1        HIGH         LOW  LAST_PRICE  NUMBER_TICKS      VOLUME       VALUE
# 2       103.7      102.02      102.69         54150      239337    24630474
# 3      103.59      102.43      103.28         75173      477955    49204884
# 4      103.94      103.01      103.34         55279      364388    37657056
#
# [5 rows x 26 columns]

# %%
df3.head()
# Out:
#         AAPL US Equity Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0              BarTp=T        NaN        NaN        NaN         NaN
# 1                 Date       OPEN       HIGH        LOW  LAST_PRICE
# 2  2016-01-04 09:30:00     102.61     102.82        102      102.26
#        AAPL US Equity Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0 2016-01-19 09:30:00      TRADE       98.41         135
# 1 2016-01-19 09:30:00      TRADE       98.42         100
# 2 2016-01-19 09:30:00      TRADE       98.41         100
# 3 2016-01-19 09:30:00   BEST_BID       98.41           2
# 4 2016-01-19 09:30:00   BEST_BID       98.43          10

# %% [markdown]
# ### Transform Data Header for sheets (Daily, 1 hr, 5min, 1min, Tick)

# %%
# rename the header
new_header = df1.iloc[0] #grab the first row for the header
df1 = df1[1:] #take the data less the header row
df1.columns = new_header #set the header row as the df header
#df = data[:]

# %% [markdown]
# #### Daily

# %%
df1.head()
# Out:
# 0                 Date PX_OPEN PX_HIGH   PX_LOW PX_LAST PX_VOLUME NUM_TRADES  \
# 1  2015-01-02 00:00:00  111.39  111.44   107.35  109.33  53204626     287276
# 2  2015-01-05 00:00:00  108.29  108.65   105.41  106.25  64285491     317900
# 3  2015-01-06 00:00:00  106.54  107.43   104.63  106.26  65797116     364285
# 4  2015-01-07 00:00:00   107.2   108.2  106.695  107.75  40105934     222430
# 5  2015-01-08 00:00:00  109.23  112.15    108.7  111.89  59364547     304607
#
# 0 VOLUME_WEIGHTED_AVG_PX
# 1                109.133
# 2                106.784
# 3                106.114
# 4                107.646
# 5                111.041

# %% [markdown]
# #### 1hr

# %%
# rename the header
new_header_2 = df2.iloc[1] #grab the first row for the header
df2_ = df2[0:] #take the data less the header row
df2_.columns = new_header_2 #set the header row as the df header
#df = data[:]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 26 columns):
# AAPL US Equity      210 non-null object
# Unnamed: 1          209 non-null object
# Unnamed: 2          209 non-null object
# Unnamed: 3          209 non-null object
# Unnamed: 4          209 non-null object
# Unnamed: 5          209 non-null object
# Unnamed: 6          209 non-null object
# Unnamed: 7          209 non-null object
# Unnamed: 8          0 non-null float64
# AAPL US Equity.1    210 non-null object
# Unnamed: 10         209 non-null object
# Unnamed: 11         209 non-null object
# Unnamed: 12         209 non-null object
# Unnamed: 13         209 non-null object
# Unnamed: 14         209 non-null object
# Unnamed: 15         209 non-null object
# Unnamed: 16         209 non-null object
# Unnamed: 17         0 non-null float64
# AAPL US Equity.2    210 non-null object
# Unnamed: 19         209 non-null object
# Unnamed: 20         209 non-null object
# Unnamed: 21         209 non-null object
# Unnamed: 22         209 non-null object
# Unnamed: 23         209 non-null object
# Unnamed: 24         209 non-null object
# Unnamed: 25         209 non-null object
# dtypes: float64(2), object(24)
# memory usage: 42.7+ KB

# %%
df2_.head()
# Out:
# 1                 Date    OPEN     HIGH     LOW  LAST_PRICE  NUMBER_TICKS  \
# 0              BarTp=T     NaN      NaN     NaN         NaN           NaN
# 1                 Date    OPEN     HIGH     LOW  LAST_PRICE  NUMBER_TICKS
# 2  2016-01-04 09:30:00  102.61   103.69     102      102.67         44010
# 3  2016-01-04 10:00:00  102.68   103.59  102.38      103.28         27462
# 4  2016-01-04 10:30:00  103.28  103.935  103.01     103.338         22162
#
# 1   VOLUME      VALUE NaN                 Date    ...        VALUE NaN  \
# 0      NaN        NaN NaN              BarTp=B    ...          NaN NaN
# 1   VOLUME      VALUE NaN                 Date    ...        VALUE NaN
# 2  9306102  956512128 NaN  2016-01-04 09:30:00    ...     31671954 NaN
# 3  4819634  496242144 NaN  2016-01-04 10:00:00    ...     47126300 NaN
# 4  3886368  401830496 NaN  2016-01-04 10:30:00    ...     40699960 NaN
#
# 1                 Date    OPEN    HIGH     LOW  LAST_PRICE  NUMBER_TICKS  \
# 0              BarTp=A     NaN     NaN     NaN         NaN           NaN
# 1                 Date    OPEN    HIGH     LOW  LAST_PRICE  NUMBER_TICKS
# 2  2016-01-04 09:30:00  102.41   103.7  102.02      102.69         54150
# 3  2016-01-04 10:00:00  102.69  103.59  102.43      103.28         75173
# 4  2016-01-04 10:30:00  103.28  103.94  103.01      103.34         55279
#
# 1  VOLUME     VALUE
# 0     NaN       NaN
# 1  VOLUME     VALUE
# 2  239337  24630474
# 3  477955  49204884
# 4  364388  37657056
#
# [5 rows x 26 columns]

# %% [markdown]
# ##### Create BarTp=T, BarTp=B, BarTp=A
# ##### 1hr: T

# %%
df2_T = df2_.iloc[:,[0,1,2,3,4,5,6,7]]

# %%
df2_T.head()
# Out:
# 1                 Date    OPEN     HIGH     LOW  LAST_PRICE  NUMBER_TICKS  \
# 0              BarTp=T     NaN      NaN     NaN         NaN           NaN
# 1                 Date    OPEN     HIGH     LOW  LAST_PRICE  NUMBER_TICKS
# 2  2016-01-04 09:30:00  102.61   103.69     102      102.67         44010
# 3  2016-01-04 10:00:00  102.68   103.59  102.38      103.28         27462
# 4  2016-01-04 10:30:00  103.28  103.935  103.01     103.338         22162
#
# 1   VOLUME      VALUE
# 0      NaN        NaN
# 1   VOLUME      VALUE
# 2  9306102  956512128
# 3  4819634  496242144
# 4  3886368  401830496

# %%
df2_T.tail()
df2_T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
# Date            210 non-null object
# OPEN            209 non-null object
# HIGH            209 non-null object
# LOW             209 non-null object
# LAST_PRICE      209 non-null object
# NUMBER_TICKS    209 non-null object
# VOLUME          209 non-null object
# VALUE           209 non-null object
# dtypes: object(8)
# memory usage: 13.2+ KB

# %%
new_header_2 = df2_T.iloc[1]

#print('old')
#print(df2_T.index)
df2_T_ = df2_T[3:] #take the data less the header row
df2_T_.columns = new_header_2 #set the header row as the df header
df2_T_.head()
# Out:
# 1                 Date    OPEN     HIGH      LOW LAST_PRICE NUMBER_TICKS  \
# 3  2016-01-04 10:00:00  102.68   103.59   102.38     103.28        27462
# 4  2016-01-04 10:30:00  103.28  103.935   103.01    103.338        22162
# 5  2016-01-04 11:00:00  103.33   103.47    102.5      103.4        18603
# 6  2016-01-04 11:30:00  103.39    103.9  103.205     103.83        14243
# 7  2016-01-04 12:00:00  103.83   104.05   103.69     103.87        12023
#
# 1   VOLUME      VALUE
# 3  4819634  496242144
# 4  3886368  401830496
# 5  3251998  335462688
# 6  2484697  257469152
# 7  2274711  236232304

# %%
new_index = [x for x in range(1,208)]
#print(new_index)
df2_T_.set_axis(new_index)
#df2_T_.reindex(start = 1, stop = 209, step =1)
#df2_T_.reset_index()
df2_T_.head()
#df2_T_.tail()
# Out:
# /Users/liyingellie/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: set_axis currently defaults to operating inplace.
# This will change in a future version of pandas, use inplace=True to avoid this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 1                 Date    OPEN     HIGH      LOW LAST_PRICE NUMBER_TICKS  \
# 1  2016-01-04 10:00:00  102.68   103.59   102.38     103.28        27462
# 2  2016-01-04 10:30:00  103.28  103.935   103.01    103.338        22162
# 3  2016-01-04 11:00:00  103.33   103.47    102.5      103.4        18603
# 4  2016-01-04 11:30:00  103.39    103.9  103.205     103.83        14243
# 5  2016-01-04 12:00:00  103.83   104.05   103.69     103.87        12023
#
# 1   VOLUME      VALUE
# 1  4819634  496242144
# 2  3886368  401830496
# 3  3251998  335462688
# 4  2484697  257469152
# 5  2274711  236232304

# %%
df2_T_.tail()
# Out:
# 1                   Date     OPEN     HIGH      LOW LAST_PRICE NUMBER_TICKS  \
# 203  2016-01-26 13:30:00  100.225   100.35  100.015    100.115        10592
# 204  2016-01-26 14:00:00  100.112  100.205    99.98    100.125        14539
# 205  2016-01-26 14:30:00  100.125   100.88   100.12    100.345        21510
# 206  2016-01-26 15:00:00  100.345  100.406    99.04      99.47        25610
# 207  2016-01-26 15:30:00    99.47   100.04    99.26      99.99        47532
#
# 1      VOLUME       VALUE
# 203   2074842   207784240
# 204   2731729   273353696
# 205   4733372   475896608
# 206   5614940   559971392
# 207  10311295  1027079104

# %% [markdown]
# ##### 1hr B

# %%
#df2_B = df2_.iloc[:,[0,1,2,3,4,5,6,7]+9]
df2_B = df2_.iloc[:,[9,10,11,12,13,14,15,16]]
df2_B.head()
# Out:
# 1                 Date    OPEN    HIGH     LOW  LAST_PRICE  NUMBER_TICKS  \
# 0              BarTp=B     NaN     NaN     NaN         NaN           NaN
# 1                 Date    OPEN    HIGH     LOW  LAST_PRICE  NUMBER_TICKS
# 2  2016-01-04 09:30:00   102.4  103.69     102      102.68         54484
# 3  2016-01-04 10:00:00  102.68  103.57  102.42      103.27         77265
# 4  2016-01-04 10:30:00  103.27  103.93     103      103.33         56858
#
# 1  VOLUME     VALUE
# 0     NaN       NaN
# 1  VOLUME     VALUE
# 2  308265  31671954
# 3  457872  47126300
# 4  393803  40699960

# %%
df2_B.tail()
# Out:
# 1                   Date    OPEN    HIGH     LOW LAST_PRICE NUMBER_TICKS  \
# 205  2016-01-26 13:30:00  100.22  100.34  100.01     100.11        30939
# 206  2016-01-26 14:00:00  100.11   100.2   99.98     100.12        26857
# 207  2016-01-26 14:30:00  100.12  100.87  100.11     100.34        40366
# 208  2016-01-26 15:00:00  100.34   100.4   99.04      99.47        58676
# 209  2016-01-26 15:30:00   99.47  100.01   99.26      99.86        72223
#
# 1    VOLUME     VALUE
# 205  292764  29315880
# 206  277772  27793882
# 207  407113  40921956
# 208  474037  47318508
# 209  873769  86996400

# %%
new_header_2_B = df2_B.iloc[1]

#print('old')
#print(df2_T.index)
df2_B_ = df2_B[3:] #take the data less the header row
df2_B_.columns = new_header_2_B #set the header row as the df header
df2_B_.head()
# Out:
# 1                 Date    OPEN    HIGH     LOW LAST_PRICE NUMBER_TICKS  \
# 3  2016-01-04 10:00:00  102.68  103.57  102.42     103.27        77265
# 4  2016-01-04 10:30:00  103.27  103.93     103     103.33        56858
# 5  2016-01-04 11:00:00  103.33  103.46  102.86     103.39        59773
# 6  2016-01-04 11:30:00  103.39  103.89   103.2     103.82        43095
# 7  2016-01-04 12:00:00  103.82  104.04  103.68     103.87        35724
#
# 1  VOLUME     VALUE
# 3  457872  47126300
# 4  393803  40699960
# 5  398852  41137492
# 6  282755  29291924
# 7  256086  26591408

# %%
df2_B_.set_axis(new_index)
#df2_T_.reindex(start = 1, stop = 209, step =1)
#df2_T_.reset_index()
df2_B_.head()
#df2_T_.tail()
# Out:
# /Users/liyingellie/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: set_axis currently defaults to operating inplace.
# This will change in a future version of pandas, use inplace=True to avoid this warning.
#   """Entry point for launching an IPython kernel.
# 1                 Date    OPEN    HIGH     LOW LAST_PRICE NUMBER_TICKS  \
# 1  2016-01-04 10:00:00  102.68  103.57  102.42     103.27        77265
# 2  2016-01-04 10:30:00  103.27  103.93     103     103.33        56858
# 3  2016-01-04 11:00:00  103.33  103.46  102.86     103.39        59773
# 4  2016-01-04 11:30:00  103.39  103.89   103.2     103.82        43095
# 5  2016-01-04 12:00:00  103.82  104.04  103.68     103.87        35724
#
# 1  VOLUME     VALUE
# 1  457872  47126300
# 2  393803  40699960
# 3  398852  41137492
# 4  282755  29291924
# 5  256086  26591408

# %% [markdown]
# ##### 1hr A

# %%
df2_A = df2_.iloc[:,[18,19,20,21,22,23,24,25]]
df2_A.head()
# Out:
# 1                 Date    OPEN    HIGH     LOW  LAST_PRICE  NUMBER_TICKS  \
# 0              BarTp=A     NaN     NaN     NaN         NaN           NaN
# 1                 Date    OPEN    HIGH     LOW  LAST_PRICE  NUMBER_TICKS
# 2  2016-01-04 09:30:00  102.41   103.7  102.02      102.69         54150
# 3  2016-01-04 10:00:00  102.69  103.59  102.43      103.28         75173
# 4  2016-01-04 10:30:00  103.28  103.94  103.01      103.34         55279
#
# 1  VOLUME     VALUE
# 0     NaN       NaN
# 1  VOLUME     VALUE
# 2  239337  24630474
# 3  477955  49204884
# 4  364388  37657056

# %%
new_header_2_A = df2_A.iloc[1]
df2_A_ = df2_B[3:] #take the data less the header row
df2_A_.columns = new_header_2_A #set the header row as the df header
df2_A_.head()
# Out:
# 1                 Date    OPEN    HIGH     LOW LAST_PRICE NUMBER_TICKS  \
# 3  2016-01-04 10:00:00  102.68  103.57  102.42     103.27        77265
# 4  2016-01-04 10:30:00  103.27  103.93     103     103.33        56858
# 5  2016-01-04 11:00:00  103.33  103.46  102.86     103.39        59773
# 6  2016-01-04 11:30:00  103.39  103.89   103.2     103.82        43095
# 7  2016-01-04 12:00:00  103.82  104.04  103.68     103.87        35724
#
# 1  VOLUME     VALUE
# 3  457872  47126300
# 4  393803  40699960
# 5  398852  41137492
# 6  282755  29291924
# 7  256086  26591408

# %%
df2_A_.set_axis(new_index)
df2_A_.head()
# Out:
# /Users/liyingellie/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: set_axis currently defaults to operating inplace.
# This will change in a future version of pandas, use inplace=True to avoid this warning.
#   """Entry point for launching an IPython kernel.
# 1                 Date    OPEN    HIGH     LOW LAST_PRICE NUMBER_TICKS  \
# 1  2016-01-04 10:00:00  102.68  103.57  102.42     103.27        77265
# 2  2016-01-04 10:30:00  103.27  103.93     103     103.33        56858
# 3  2016-01-04 11:00:00  103.33  103.46  102.86     103.39        59773
# 4  2016-01-04 11:30:00  103.39  103.89   103.2     103.82        43095
# 5  2016-01-04 12:00:00  103.82  104.04  103.68     103.87        35724
#
# 1  VOLUME     VALUE
# 1  457872  47126300
# 2  393803  40699960
# 3  398852  41137492
# 4  282755  29291924
# 5  256086  26591408

# %% [markdown]
# #### 5 min

# %%
print(df3.info())
df3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 860 entries, 0 to 859
# Data columns (total 26 columns):
# AAPL US Equity      860 non-null object
# Unnamed: 1          859 non-null object
# Unnamed: 2          859 non-null object
# Unnamed: 3          859 non-null object
# Unnamed: 4          859 non-null object
# Unnamed: 5          859 non-null object
# Unnamed: 6          859 non-null object
# Unnamed: 7          859 non-null object
# Unnamed: 8          0 non-null float64
# AAPL US Equity.1    860 non-null object
# Unnamed: 10         859 non-null object
# Unnamed: 11         859 non-null object
# Unnamed: 12         859 non-null object
# Unnamed: 13         859 non-null object
# Unnamed: 14         859 non-null object
# Unnamed: 15         859 non-null object
# Unnamed: 16         859 non-null object
# Unnamed: 17         0 non-null float64
# AAPL US Equity.2    860 non-null object
# Unnamed: 19         859 non-null object
# Unnamed: 20         859 non-null object
# Unnamed: 21         859 non-null object
# Unnamed: 22         859 non-null object
# Unnamed: 23         859 non-null object
# Unnamed: 24         859 non-null object
# Unnamed: 25         859 non-null object
# dtypes: float64(2), object(24)
# memory usage: 174.8+ KB
# None
#         AAPL US Equity Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0              BarTp=T        NaN        NaN        NaN         NaN
# 1                 Date       OPEN       HIGH        LOW  LAST_PRICE
# 2  2016-01-04 09:30:00     102.61     102.82        102      102.26
# 3  2016-01-04 09:35:00     102.25     103.61     102.25       103.5
# 4  2016-01-04 09:40:00      103.5     103.69      102.6      102.61
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8     AAPL US Equity.1  \
# 0           NaN        NaN        NaN         NaN              BarTp=B
# 1  NUMBER_TICKS     VOLUME      VALUE         NaN                 Date
# 2         10739    3056906  312927488         NaN  2016-01-04 09:30:00
# 3         10190    1902193  195863984         NaN  2016-01-04 09:35:00
# 4          8763    1801690  185863856         NaN  2016-01-04 09:40:00
#
#       ...       Unnamed: 16 Unnamed: 17     AAPL US Equity.2 Unnamed: 19  \
# 0     ...               NaN         NaN              BarTp=A         NaN
# 1     ...             VALUE         NaN                 Date        OPEN
# 2     ...           7673177         NaN  2016-01-04 09:30:00      102.41
# 3     ...       4.06626e+06         NaN  2016-01-04 09:35:00      102.26
# 4     ...        3.5023e+06         NaN  2016-01-04 09:40:00      103.52
#
#   Unnamed: 20 Unnamed: 21 Unnamed: 22   Unnamed: 23 Unnamed: 24  Unnamed: 25
# 0         NaN         NaN         NaN           NaN         NaN          NaN
# 1        HIGH         LOW  LAST_PRICE  NUMBER_TICKS      VOLUME        VALUE
# 2      102.82      102.02      102.27          5847       19544  2.00037e+06
# 3      103.62      102.26      103.52         10194       55363  5.69834e+06
# 4       103.7      102.61      102.64          9310       34957   3.6078e+06
#
# [5 rows x 26 columns]

# %% [markdown]
# ##### Create BarTp=T, BarTp=B, BarTp=A
# ##### 5 min T

# %%
df3_T = df3.iloc[:,[0,1,2,3,4,5,6,7]]
new_header_3 = df3_T.iloc[1]


df3_T_ = df3_T[3:] #take the data less the header row
df3_T_.columns = new_header_3 #set the header row as the df header
print(df3_T_.info())
print(df3_T_.head())
print(df3_T_.tail())
#df3_T_.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 3 to 859
# Data columns (total 8 columns):
# Date            857 non-null object
# OPEN            857 non-null object
# HIGH            857 non-null object
# LOW             857 non-null object
# LAST_PRICE      857 non-null object
# NUMBER_TICKS    857 non-null object
# VOLUME          857 non-null object
# VALUE           857 non-null object
# dtypes: object(8)
# memory usage: 53.6+ KB
# None
# 1                 Date     OPEN    HIGH     LOW LAST_PRICE NUMBER_TICKS  \
# 3  2016-01-04 09:35:00   102.25  103.61  102.25      103.5        10190
# 4  2016-01-04 09:40:00    103.5  103.69   102.6     102.61         8763
# 5  2016-01-04 09:45:00  102.634  103.23  102.43     103.02         5522
# 6  2016-01-04 09:50:00   103.02  103.06  102.85     102.87         5115
# 7  2016-01-04 09:55:00  102.865  102.94  102.67     102.67         3681
#
# 1   VOLUME      VALUE
# 3  1902193  195863984
# 4  1801690  185863856
# 5  1045341  107526968
# 6   835372   86006840
# 7   664600   68322960
# 1                   Date    OPEN   HIGH    LOW LAST_PRICE NUMBER_TICKS  \
# 855  2016-01-19 15:35:00   96.76  96.85  96.63     96.759         2793
# 856  2016-01-19 15:40:00  96.751  96.92   96.6      96.88         4336
# 857  2016-01-19 15:45:00   96.89     97  96.72      96.98         4299
# 858  2016-01-19 15:50:00   96.98     97  96.85      96.95         4702
# 859  2016-01-19 15:55:00   96.95  96.96  96.65      96.66         6495
#
# 1     VOLUME      VALUE
# 855   524556   50742864
# 856   831632   80502416
# 857   861899   83523592
# 858   911260   88337808
# 859  2888449  279378624

# %%
new_index2 = [x for x in range(1,858)]
df3_T_.set_axis(new_index2)
print(df3_T_.info())
print(df3_T_.head())
print(df3_T_.tail())
df3_T_.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 857 entries, 1 to 857
# Data columns (total 8 columns):
# Date            857 non-null object
# OPEN            857 non-null object
# HIGH            857 non-null object
# LOW             857 non-null object
# LAST_PRICE      857 non-null object
# NUMBER_TICKS    857 non-null object
# VOLUME          857 non-null object
# VALUE           857 non-null object
# dtypes: object(8)
# memory usage: 60.3+ KB
# None
# 1                 Date     OPEN    HIGH     LOW LAST_PRICE NUMBER_TICKS  \
# 1  2016-01-04 09:35:00   102.25  103.61  102.25      103.5        10190
# 2  2016-01-04 09:40:00    103.5  103.69   102.6     102.61         8763
# 3  2016-01-04 09:45:00  102.634  103.23  102.43     103.02         5522
# 4  2016-01-04 09:50:00   103.02  103.06  102.85     102.87         5115
# 5  2016-01-04 09:55:00  102.865  102.94  102.67     102.67         3681
#
# 1   VOLUME      VALUE
# 1  1902193  195863984
# 2  1801690  185863856
# 3  1045341  107526968
# 4   835372   86006840
# 5   664600   68322960
# 1                   Date    OPEN   HIGH    LOW LAST_PRICE NUMBER_TICKS  \
# 853  2016-01-19 15:35:00   96.76  96.85  96.63     96.759         2793
# 854  2016-01-19 15:40:00  96.751  96.92   96.6      96.88         4336
# 855  2016-01-19 15:45:00   96.89     97  96.72      96.98         4299
# 856  2016-01-19 15:50:00   96.98     97  96.85      96.95         4702
# 857  2016-01-19 15:55:00   96.95  96.96  96.65      96.66         6495
#
# 1     VOLUME      VALUE
# 853   524556   50742864
# 854   831632   80502416
# 855   861899   83523592
# 856   911260   88337808
# 857  2888449  279378624
# /Users/liyingellie/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: set_axis currently defaults to operating inplace.
# This will change in a future version of pandas, use inplace=True to avoid this warning.
# 1                 Date     OPEN    HIGH     LOW LAST_PRICE NUMBER_TICKS  \
# 1  2016-01-04 09:35:00   102.25  103.61  102.25      103.5        10190
# 2  2016-01-04 09:40:00    103.5  103.69   102.6     102.61         8763
# 3  2016-01-04 09:45:00  102.634  103.23  102.43     103.02         5522
# 4  2016-01-04 09:50:00   103.02  103.06  102.85     102.87         5115
# 5  2016-01-04 09:55:00  102.865  102.94  102.67     102.67         3681
#
# 1   VOLUME      VALUE
# 1  1902193  195863984
# 2  1801690  185863856
# 3  1045341  107526968
# 4   835372   86006840
# 5   664600   68322960

# %% [markdown]
# ##### 5 min B

# %%
df3_B = df3.iloc[:,[9,10,11,12,13,14,15,16]]
new_header_3 = df3_T.iloc[1]


df3_B_ = df3_B[3:] #take the data less the header row
df3_B_.columns = new_header_3 #set the header row as the df header
print(df3_B_.info())
print(df3_B_.head())
print(df3_B_.tail())
#df3_T_.head()

new_index2 = [x for x in range(1,858)]
df3_B_.set_axis(new_index2)
print(df3_B_.info())
print(df3_B_.head())
print(df3_B_.tail())
df3_B_.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 3 to 859
# Data columns (total 8 columns):
# Date            857 non-null object
# OPEN            857 non-null object
# HIGH            857 non-null object
# LOW             857 non-null object
# LAST_PRICE      857 non-null object
# NUMBER_TICKS    857 non-null object
# VOLUME          857 non-null object
# VALUE           857 non-null object
# dtypes: object(8)
# memory usage: 53.6+ KB
# None
# 1                 Date    OPEN    HIGH     LOW LAST_PRICE NUMBER_TICKS VOLUME  \
# 3  2016-01-04 09:35:00  102.25  103.61  102.25      103.5        10332  39510
# 4  2016-01-04 09:40:00  103.51  103.69   102.6      102.6         7967  33929
# 5  2016-01-04 09:45:00   102.6  103.21  102.42     103.01         9977  48495
# 6  2016-01-04 09:50:00  103.01  103.05  102.84     102.86        12685  68139
# 7  2016-01-04 09:55:00  102.86  102.94  102.66     102.68         7762  43047
#
# 1        VALUE
# 3  4.06626e+06
# 4   3.5023e+06
# 5  4.99062e+06
# 6      7014776
# 7  4.42503e+06
# 1                   Date   OPEN   HIGH    LOW LAST_PRICE NUMBER_TICKS  VOLUME  \
# 855  2016-01-19 15:35:00  96.75  96.84  96.63      96.74        13982   90783
# 856  2016-01-19 15:40:00  96.74  96.91   96.6      96.88        15354  111771
# 857  2016-01-19 15:45:00  96.88  96.99  96.71      96.97        13423   94125
# 858  2016-01-19 15:50:00  96.97     97  96.85      96.94         9896   90650
# 859  2016-01-19 15:55:00  96.94  96.95  96.64      96.64         8240  124007
#
# 1       VALUE
# 855   8781292
# 856  10817440
# 857   9119975
# 858   8786691
# 859  12003980
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 857 entries, 1 to 857
# Data columns (total 8 columns):
# Date            857 non-null object
# OPEN            857 non-null object
# HIGH            857 non-null object
# LOW             857 non-null object
# LAST_PRICE      857 non-null object
# NUMBER_TICKS    857 non-null object
# VOLUME          857 non-null object
# VALUE           857 non-null object
# dtypes: object(8)
# memory usage: 60.3+ KB
# None
# 1                 Date    OPEN    HIGH     LOW LAST_PRICE NUMBER_TICKS VOLUME  \
# 1  2016-01-04 09:35:00  102.25  103.61  102.25      103.5        10332  39510
# 2  2016-01-04 09:40:00  103.51  103.69   102.6      102.6         7967  33929
# 3  2016-01-04 09:45:00   102.6  103.21  102.42     103.01         9977  48495
# 4  2016-01-04 09:50:00  103.01  103.05  102.84     102.86        12685  68139
# 5  2016-01-04 09:55:00  102.86  102.94  102.66     102.68         7762  43047
#
# 1        VALUE
# 1  4.06626e+06
# 2   3.5023e+06
# 3  4.99062e+06
# 4      7014776
# 5  4.42503e+06
# 1                   Date   OPEN   HIGH    LOW LAST_PRICE NUMBER_TICKS  VOLUME  \
# 853  2016-01-19 15:35:00  96.75  96.84  96.63      96.74        13982   90783
# 854  2016-01-19 15:40:00  96.74  96.91   96.6      96.88        15354  111771
# 855  2016-01-19 15:45:00  96.88  96.99  96.71      96.97        13423   94125
# 856  2016-01-19 15:50:00  96.97     97  96.85      96.94         9896   90650
# 857  2016-01-19 15:55:00  96.94  96.95  96.64      96.64         8240  124007
#
# 1       VALUE
# 853   8781292
# 854  10817440
# 855   9119975
# 856   8786691
# 857  12003980
# /Users/liyingellie/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: set_axis currently defaults to operating inplace.
# This will change in a future version of pandas, use inplace=True to avoid this warning.
#   del sys.path[0]
# 1                 Date    OPEN    HIGH     LOW LAST_PRICE NUMBER_TICKS VOLUME  \
# 1  2016-01-04 09:35:00  102.25  103.61  102.25      103.5        10332  39510
# 2  2016-01-04 09:40:00  103.51  103.69   102.6      102.6         7967  33929
# 3  2016-01-04 09:45:00   102.6  103.21  102.42     103.01         9977  48495
# 4  2016-01-04 09:50:00  103.01  103.05  102.84     102.86        12685  68139
# 5  2016-01-04 09:55:00  102.86  102.94  102.66     102.68         7762  43047
#
# 1        VALUE
# 1  4.06626e+06
# 2   3.5023e+06
# 3  4.99062e+06
# 4      7014776
# 5  4.42503e+06

# %% [markdown]
# ##### 5 min A

# %%
df3_A = df3.iloc[:,[18,19,20,21,22,23,24,25]]
new_header_3 = df3_T.iloc[1]


df3_A_ = df3_B[3:] #take the data less the header row
df3_A_.columns = new_header_3 #set the header row as the df header
print(df3_A_.info())
print(df3_A_.head())
print(df3_A_.tail())
#df3_T_.head()

new_index2 = [x for x in range(1,858)]
df3_A_.set_axis(new_index2)
print(df3_A_.info())
print(df3_A_.head())
print(df3_A_.tail())
df3_A_.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex:
# [5 rows x 26 columns]

# %% [markdown]
# ##### Create BarTp=T, BarTp=B, BarTp=A
# ##### 1 min T

# %%
df4_T = df4.iloc[:,[0,1,2,3,4,5,6,7]]
new_header_4 = df4_T.iloc[1]


df4_T_ = df4_T[3:] #take the data less the header row
df4_T_.columns = new_header_4 #set the header row as the df header
print(df4_T_.info())
print(df4_T_.head())
print(df4_T_.tail())
df3_T_.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 3 to 391
# Data columns (total 8 columns):
# Date            389 non-null object
# OPEN            389 non-null object
# HIGH            389 non-null object
# LOW             389 non-null object
# LAST_PRICE      389 non-null object
# NUMBER_TICKS    389 non-null object
# VOLUME          389 non-null object
# VALUE           389 non-null object
# dtypes: object(8)
# memory usage: 24.4+ KB
# None
# 1                 Date     OPEN     HIGH    LOW LAST_PRICE NUMBER_TICKS  \
# 3  2016-01-19 09:31:00  98.3314    98.65   98.3      98.44         1337
# 4  2016-01-19 09:32:00    98.43  98.5399  98.35      98.43          895
# 5  2016-01-19 09:33:00    98.43    98.44  98.24      98.34         1000
# 6  2016-01-19 09:34:00  98.3499    98.39   98.2      98.26          765
# 7  2016-01-19 09:35:00    98.28    98.31  98.08      98.17         1081
#
# 1  VOLUME     VALUE
# 3  290059  28572824
# 4  148454  14613426
# 5  251992  24782496
# 6  155654  15298748
# 7  237559  23329222
# 1                   Date    OPEN     HIGH     LOW LAST_PRICE NUMBER_TICKS  \
# 387  2016-01-19 15:55:00   96.95    96.96  96.881      96.95         1174
# 388  2016-01-19 15:56:00   96.95    96.95   96.85    96.8942          779
# 389  2016-01-19 15:57:00  96.895    96.91   96.74      96.81         1316
# 390  2016-01-19 15:58:00  96.805  96.8199   96.73      96.77         1326
# 391  2016-01-19 15:59:00  96.765     96.8   96.65      96.66         1900
#
# 1     VOLUME      VALUE
# 387   212968   20641848
# 388   127309   12335658
# 389   275096   26630482
# 390   245807   23786116
# 391  2027269  195984528
# 1                 Date     OPEN    HIGH     LOW LAST_PRICE NUMBER_TICKS  \
# 1  2016-01-04 09:35:00   102.25  103.61  102.25      103.5        10190
# 2  2016-01-04 09:40:00    103.5  103.69   102.6     102.61         8763
# 3  2016-01-04 09:45:00  102.634  103.23  102.43     103.02         5522
# 4  2016-01-04 09:50:00   103.02  103.06  102.85     102.87         5115
# 5  2016-01-04 09:55:00  102.865  102.94  102.67     102.67         3681
#
# 1   VOLUME      VALUE
# 1  1902193  195863984
# 2  1801690  185863856
# 3  1045341  107526968
# 4   835372   86006840
# 5   664600   68322960

# %% [markdown]
# ##### 1 min B

# %%
df4_B = df4.iloc[:,[9,10,11,12,13,14,15,16]]
new_header_4 = df4_T.iloc[1]


df4_B_ = df4_B[3:] #take the data less the header row
df4_B_.columns = new_header_4 #set the header row as the df header
print(df4_B_.info())
print(df4_B_.head())
print(df4_B_.tail())
#df3_T_.head()

new_index2 = [x for x in range(1,390)]
df4_B_.set_axis(new_index2)
print(df4_B_.info())
print(df4_B_.head())
print(df4_B_.tail())
df4_B_.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex:
anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: set_axis currently defaults to operating inplace.
# This will change in a future version of pandas, use inplace=True to avoid this warning.
#   del sys.path[0]
# 1                 Date   OPEN   HIGH    LOW LAST_PRICE NUMBER_TICKS VOLUME  \
# 1  2016-01-19 09:31:00  98.33  98.64  98.27      98.42          916   3434
# 2  2016-01-19 09:32:00  98.42  98.52  98.34      98.43          838   2743
# 3  2016-01-19 09:33:00  98.43  98.43  98.22      98.34          806   5607
# 4  2016-01-19 09:34:00  98.34  98.38   98.2      98.25          725   3749
# 5  2016-01-19 09:35:00  98.25   98.3  98.08      98.14         1230   7695
#
# 1   VALUE
# 1  338298
# 2  269990
# 3  551345
# 4  368452
# 5  755546

# %% [markdown]
# ##### 1 min A

# %%
df4_A = df3.iloc[:,[18,19,20,21,22,23,24,25]]
new_header_4 = df4_T.iloc[1]


df4_A_ = df4_B[3:] #take the data less the header row
df4_A_.columns = new_header_4 #set the header row as the df header
print(df4_A_.info())
print(df4_A_.head())
print(df4_A_.tail())
#df3_T_.head()

new_index2 = [x for x in range(1,390)]
df4_A_.set_axis(new_index2)
print(df4_A_.info())
print(df4_A_.head())
print(df4_A_.tail())
df4_A_.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 3 to 391
# Data columns (total 8 columns):
# Date            389 non-null object
# OPEN            389 non-null object
# HIGH            389 non-null object
# LOW             389 non-null object
# LAST_PRICE      389 non-null object
# NUMBER_TICKS    389 non-null object
# VOLUME          389 non-null object
# VALUE           389 non-null object
# dtypes: object(8)
# memory usage: 24.4+ KB
# None
# 1                 Date   OPEN   HIGH    LOW LAST_PRICE NUMBER_TICKS VOLUME  \
# 3  2016-01-19 09:31:00  98.33  98.64  98.27      98.42          916   3434
# 4  2016-01-19 09:32:00  98.42  98.52  98.34      98.43          838   2743
# 5  2016-01-19 09:33:00  98.43  98.43  98.22      98.34          806   5607
# 6  2016-01-19 09:34:00  98.34  98.38   98.2      98.25          725   3749
# 7  2016-01-19 09:35:00  98.25   98.3  98.08      98.14         1230   7695
#
# 1   VALUE
# 3  338298
# 4  269990
# 5  551345
# 6  368452
# 7  755546
# 1                   Date   OPEN   HIGH    LOW LAST_PRICE NUMBER_TICKS VOLUME  \
# 387  2016-01-19 15:55:00  96.94  96.95  96.88      96.94         1919  20369
# 388  2016-01-19 15:56:00  96.94  96.95  96.85      96.89         1695  16755
# 389  2016-01-19 15:57:00  96.89   96.9  96.73       96.8         1942  36341
# 390  2016-01-19 15:58:00   96.8  96.81  96.73      96.76         1021   7095
# 391  2016-01-19 15:59:00  96.76  96.79  96.64      96.64         1663  43447
#
# 1          VALUE
# 387  1.97412e+06
# 388  1.62335e+06
# 389  3.51694e+06
# 390       686552
# 391  4.20302e+06
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 1 to 389
# Data columns (total 8 columns):
# Date            389 non-null object
# OPEN            389 non-null object
# HIGH            389 non-null object
# LOW             389 non-null object
# LAST_PRICE      389 non-null object
# NUMBER_TICKS    389 non-null object
# VOLUME          389 non-null object
# VALUE           389 non-null object
# dtypes: object(8)
# memory usage: 27.4+ KB
# None
# 1                 Date   OPEN   HIGH    LOW LAST_PRICE NUMBER_TICKS VOLUME  \
# 1  2016-01-19 09:31:00  98.33  98.64  98.27      98.42          916   3434
# 2  2016-01-19 09:32:00  98.42  98.52  98.34      98.43          838   2743
# 3  2016-01-19 09:33:00  98.43  98.43  98.22      98.34          806   5607
# 4  2016-01-19 09:34:00  98.34  98.38   98.2      98.25          725   3749
# 5  2016-01-19 09:35:00  98.25   98.3  98.08      98.14         1230   7695
#
# 1   VALUE
# 1  338298
# 2  269990
# 3  551345
# 4  368452
# 5  755546
# 1                   Date   OPEN   HIGH    LOW LAST_PRICE NUMBER_TICKS VOLUME  \
# 385  2016-01-19 15:55:00  96.94  96.95  96.88      96.94         1919  20369
# 386  2016-01-19 15:56:00  96.94  96.95  96.85      96.89         1695  16755
# 387  2016-01-19 15:57:00  96.89   96.9  96.73       96.8         1942  36341
# 388  2016-01-19 15:58:00   96.8  96.81  96.73      96.76         1021   7095
# 389  2016-01-19 15:59:00  96.76  96.79  96.64      96.64         1663  43447
#
# 1          VALUE
# 385  1.97412e+06
# 386  1.62335e+06
# 387  3.51694e+06
# 388       686552
# 389  4.20302e+06
# /Users/liyingellie/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: set_axis currently defaults to operating inplace.
# This will change in a future version of pandas, use inplace=True to avoid this warning.
#   del sys.path[0]
# 1                 Date   OPEN   HIGH    LOW LAST_PRICE NUMBER_TICKS VOLUME  \
# 1  2016-01-19 09:31:00  98.33  98.64  98.27      98.42          916   3434
# 2  2016-01-19 09:32:00  98.42  98.52  98.34      98.43          838   2743
# 3  2016-01-19 09:33:00  98.43  98.43  98.22      98.34          806   5607
# 4  2016-01-19 09:34:00  98.34  98.38   98.2      98.25          725   3749
# 5  2016-01-19 09:35:00  98.25   98.3  98.08      98.14         1230   7695
#
# 1   VALUE
# 1  338298
# 2  269990
# 3  551345
# 4  368452
# 5  755546

# %% [markdown]
# ### Tick

# %%
print(df5.info())
df5.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49262 entries, 0 to 49261
# Data columns (total 4 columns):
# AAPL US Equity    49262 non-null datetime64[ns]
# Unnamed: 1        49262 non-null object
# Unnamed: 2        49262 non-null float64
# Unnamed: 3        49262 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 1.5+ MB
# None
#        AAPL US Equity Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0 2016-01-19 09:30:00      TRADE       98.41         135
# 1 2016-01-19 09:30:00      TRADE       98.42         100
# 2 2016-01-19 09:30:00      TRADE       98.41         100
# 3 2016-01-19 09:30:00   BEST_BID       98.41           2
# 4 2016-01-19 09:30:00   BEST_BID       98.43          10

# %% [markdown]
# # Exercise 1
# In this exercise, we will conduct analysis of the daily transaction data (corresponding to data in ‘daily’ worksheet). Note: here PX_OPEN, PX_HIGH, PX_LOW and PX_LAST represent, respectively, the daily opening price, daily high, daily low and daily closing prices. PX_VOLUME represents the total daily trade volume, NUM_TRADES represents the number of transactions (trades) during the day, VOLUME_WEIGHTED_AVG_PX represents the calculated daily VWAP.

# %% [markdown]
# ## 1.1 Compute the mean, median, standard deviation, skewness, kurtosis and autocorrelations (with lag 1, 5, 10) of the daily opening, high, low and closing prices.

# %%
def get_summary(name):
    print(name)
    print("mean: " + str(df1[name].mean()))
    print("median: " + str(df1[name].median()))
    print("standard deviation: " + str(df1[name].std()))
    print("skewness : " + str(df1[name].skew()))
    print("kurtosis: " + str(df1[name].kurtosis()))

# %%
def get_autocorr(name, type_):
    
    s = df1[name].astype(float) # convert object to float 
    print(name +' autocorrelations'+ " lag: "+ str(type_))
    
    print(s.autocorr(lag=type_))

# %%
print('----------------------------------------')
get_summary('PX_OPEN')
print('----------------------------------------')
get_summary('PX_HIGH')
print('----------------------------------------')
get_summary('PX_LOW')
print('----------------------------------------')
get_summary('PX_LAST')
print('----------------------------------------')
# Out:
# ----------------------------------------
# PX_OPEN
# mean: 120.16992063492067
# median: 120.48
# standard deviation: 7.688692102604718
# skewness : -0.24202787417880534
# kurtosis: -0.9952486211406861
# ----------------------------------------
# PX_HIGH
# mean: 121.24145793650791
# median: 121.58500000000001
# standard deviation: 7.46273245590533
# skewness : -0.16617554990063033
# kurtosis: -1.3016132903809619
# ----------------------------------------
# PX_LOW
# mean: 118.86294841269844
# median: 119.35
# standard deviation: 7.917445376428092
# skewness : -0.30164110376581954
# kurtosis: -0.9391214713179061
# ----------------------------------------
# PX_LAST
# mean: 120.03986111111111
# median: 120.3
# standard deviation: 7.68344731419663
# skewness : -0.22004018492959612
# kurtosis: -1.227350980210895
# ----------------------------------------

# %%
print('---------------------------------')
get_autocorr('PX_OPEN', 1)
get_autocorr('PX_OPEN', 5)
get_autocorr('PX_OPEN', 10)
print('---------------------------------')
get_autocorr('PX_HIGH', 1)
get_autocorr('PX_HIGH', 5)
get_autocorr('PX_HIGH', 10)
print('---------------------------------')
get_autocorr('PX_LOW', 1)
get_autocorr('PX_LOW', 5)
get_autocorr('PX_LOW', 10)
print('---------------------------------')
get_autocorr('PX_LAST', 1)
get_autocorr('PX_LAST', 5)
get_autocorr('PX_LAST', 10)
print('---------------------------------')
# Out:
# ---------------------------------
# PX_OPEN autocorrelations lag: 1
# 0.9498159534658349
# PX_OPEN autocorrelations lag: 5
# 0.8524093931659571
# PX_OPEN autocorrelations lag: 10
# 0.7428323728448338
# ---------------------------------
# PX_HIGH autocorrelations lag: 1
# 0.9777126237752591
# PX_HIGH autocorrelations lag: 5
# 0.8801106168666017
# PX_HIGH autocorrelations lag: 10
# 0.7546760272411648
# ---------------------------------
# PX_LOW autocorrelations lag: 1
# 0.9636258527460955
# PX_LOW autocorrelations lag: 5
# 0.8452690827871716
# PX_LOW autocorrelations lag: 10
# 0.7289539129336101
# ---------------------------------
# PX_LAST autocorrelations lag: 1
# 0.9668718777146416
# PX_LAST autocorrelations lag: 5
# 0.8594915893419641
# PX_LAST autocorrelations lag: 10
# 0.7343014464824434
# ---------------------------------

# %% [markdown]
# ## 1.2 Repeat this exercise for daily number of trades, volume and VWAP.

# %%
print('----------------------------------------')
get_summary('NUM_TRADES')
print('----------------------------------------')
get_summary('PX_VOLUME')
print('----------------------------------------')
get_summary('VOLUME_WEIGHTED_AVG_PX')
print('----------------------------------------')
# Out:
# ----------------------------------------
# NUM_TRADES
# mean: 257727.16666666666
# median: 231172.5
# standard deviation: 116937.09330341249
# skewness : 1.8463570005230667
# kurtosis: 5.3340647095186995
# ----------------------------------------
# PX_VOLUME
# mean: 51858815.28571428
# median: 47336269.5
# standard deviation: 21173740.616441313
# skewness : 1.8103831475235617
# kurtosis: 5.003788803558676
# ----------------------------------------
# VOLUME_WEIGHTED_AVG_PX
# mean: 120.07377301587299
# median: 120.50280000000001
# standard deviation: 7.633040780741589
# skewness : -0.20319786700581136
# kurtosis: -1.2841140075742628
# ----------------------------------------

# %%
print('---------------------------------')
get_autocorr('NUM_TRADES', 1)
get_autocorr('NUM_TRADES', 5)
get_autocorr('NUM_TRADES', 10)
print('---------------------------------')
get_autocorr('PX_VOLUME', 1)
get_autocorr('PX_VOLUME', 5)
get_autocorr('PX_VOLUME', 10)
print('---------------------------------')
get_autocorr('VOLUME_WEIGHTED_AVG_PX', 1)
get_autocorr('VOLUME_WEIGHTED_AVG_PX', 5)
get_autocorr('VOLUME_WEIGHTED_AVG_PX', 10)
print('---------------------------------')
# Out:
# ---------------------------------
# NUM_TRADES autocorrelations lag: 1
# 0.6858574384654654
# NUM_TRADES autocorrelations lag: 5
# 0.15346687212810103
# NUM_TRADES autocorrelations lag: 10
# 0.2942193568271449
# ---------------------------------
# PX_VOLUME autocorrelations lag: 1
# 0.6065223685953881
# PX_VOLUME autocorrelations lag: 5
# 0.04482201634085162
# PX_VOLUME autocorrelations lag: 10
# 0.18134087004377894
# ---------------------------------
# VOLUME_WEIGHTED_AVG_PX autocorrelations lag: 1
# 0.9765196992676498
# VOLUME_WEIGHTED_AVG_PX autocorrelations lag: 5
# 0.8729027596927988
# VOLUME_WEIGHTED_AVG_PX autocorrelations lag: 10
# 0.7496542653910858
# ---------------------------------

# %%
df1.head()
# Out:
# 0                 Date PX_OPEN PX_HIGH   PX_LOW PX_LAST PX_VOLUME NUM_TRADES  \
# 1  2015-01-02 00:00:00  111.39  111.44   107.35  109.33  53204626     287276
# 2  2015-01-05 00:00:00  108.29  108.65   105.41  106.25  64285491     317900
# 3  2015-01-06 00:00:00  106.54  107.43   104.63  106.26  65797116     364285
# 4  2015-01-07 00:00:00   107.2   108.2  106.695  107.75  40105934     222430
# 5  2015-01-08 00:00:00  109.23  112.15    108.7  111.89  59364547     304607
#
# 0 VOLUME_WEIGHTED_AVG_PX
# 1                109.133
# 2                106.784
# 3                106.114
# 4                107.646
# 5                111.041

# %% [markdown]
# ## 2.1 Create a histogram (representing the distribution function) of closing price, volume and VWAP from the daily transaction data with 10 bins.

# %%
df1['PX_LAST'].plot.hist()

# %%
df1['PX_VOLUME'].plot.hist()

# %%
df1['VOLUME_WEIGHTED_AVG_PX'].plot.hist()

# %% [markdown]
# ## 2.2 Repeat this exercise with 20 bins.

# %%
df1['PX_LAST'].plot.hist(bins=20)

# %%
df1['PX_VOLUME'].plot.hist(bins=20)

# %%
df1['VOLUME_WEIGHTED_AVG_PX'].plot.hist(bins=20)

# %% [markdown]
# ## 3.1 Compute the daily tracking error between closing price and VWAP data series (using actual data).

# %% [markdown]
# ## 3.2 Repeat this exercise with daily return data for both series. Note: Tracking error is defined as standard deviation of the difference between the two time series).

# %% [markdown]
# ## 4.1 Compute the correlation between 5-day changes of the closing price and volume (corresponding to weekly changes).

# %% [markdown]
# ## 4.2 Furthermore, compute the slope and R-squared of the linear regression line and create a scatter plot showing the relationship between these two weekly change series.

# %% [markdown]
# ## 4.3 Repeat this exercise for closing price and number of trades.
